# %% [markdown]
# # Pythonga kirish — Dars 1
# ## Amaliy mashqlar
#
# **Mavzular:** `print`, o'zgaruvchilar, ma'lumot turlari, `input`, f-satrlar, amallar, shartlar `if / elif / else`
#
# Vazifalar ketma-ket bajariladi. `pass` ni o'z kodingiz bilan almashtiring va katakni ishga tushiring (Shift + Enter).

# %% [markdown]
# ---
# ## Vazifa 1. Tanishuv kartasi
#
# Foydalanuvchidan ism, familiya va shaharni so'rang. f-satr orqali chiroyli karta chiqaring.
#
# **Chiqarish namunasi:**
# ```
# Ism:       Mirkomil
# Familiya:  Karimov
# Shahar:    Toshkent
# ```

# %%
# Kodingizni shu yerga yozing
pass

# %% [markdown]
# ---
# ## Vazifa 2. To'rtburchak yuzi va perimetri
#
# To'rtburchakning uzunligi va kengligini so'rang. Yuzi va perimetrini chiqaring.
#
# **Maslahat:** kasr sonlar uchun `float()` ishlating.
#
# **Chiqarish namunasi:**
# ```
# Yuzi:      15.0
# Perimetr:  16.0
# ```

# %%
# Kodingizni shu yerga yozing
pass

# %% [markdown]
# ---
# ## Vazifa 3. Harorat konvertori
#
# Selsiy bo'yicha haroratni so'rang. Farengeyt qiymatini chiqaring.
#
# **Formula:** F = C × 9/5 + 32
#
# **Chiqarish namunasi:**
# ```
# 0°C = 32.0°F
# ```

# %%
# Kodingizni shu yerga yozing
pass

# %% [markdown]
# ---
# ## Vazifa 4. Chayyon (tip) kalkulyatori
#
# Hisob summasini va chayyon foizini so'rang. Chayyon miqdori va umumiy summani chiqaring.
#
# **Chiqarish namunasi:**
# ```
# Hisob summasi:   1000
# Chayyon (10%):   100.0
# Jami:            1100.0
# ```

# %%
# Kodingizni shu yerga yozing
pass

# %% [markdown]
# ---
# ## Vazifa 5. Sonning juftligi
#
# Butun son so'rang. Quyidagilarni chiqaring:
# - «Nol» - agar son nolga teng bo'lsa
# - «Juft» - agar 2 ga qoldiqsiz bo'linsa
# - «Toq» - aks holda
#
# **Maslahat:** `%` operatori bo'lishdan qoldiqni qaytaradi.

# %%
# Kodingizni shu yerga yozing
pass

# %% [markdown]
# ---
# ## Vazifa 6. Baholar kalkulyatori
#
# 0 dan 100 gacha bo'lgan ballni so'rang. Harf bahosini chiqaring.
#
# | Ball | Baho |
# |---|---|
# | ≥ 90 | A |
# | ≥ 80 | B |
# | ≥ 70 | C |
# | ≥ 60 | D |
# | < 60 | F |

# %%
# Kodingizni shu yerga yozing
pass

# %% [markdown]
# ---
# ## Vazifa 7. Yosh toifasi
#
# Yoshni so'rang. Toifani chiqaring.
#
# | Yosh | Toifa |
# |---|---|
# | 0–12 | Bola |
# | 13–17 | O'smir |
# | 18–64 | Kattalar |
# | 65+ | Pensioner |

# %%
# Kodingizni shu yerga yozing
pass

# %% [markdown]
# ---
# ## Vazifa 8. Kabisa yili
#
# Yilni so'rang. Uning kabisa yili ekanligini aniqlang.
#
# **Qoida:** yil 4 ga bo'linsa kabisa yili hisoblanadi, agar 100 ga bo'linsa va 400 ga bo'linmasa - bundan mustasno.
#
# **Misollar:**
# - 2024 → kabisa yili (4 ga bo'linadi, 100 ga emas)
# - 2000 → kabisa yili (400 ga bo'linadi)
# - 1900 → kabisa yili emas (100 ga bo'linadi, 400 ga emas)
# - 2023 → kabisa yili emas (4 ga bo'linmaydi)

# %%
# Kodingizni shu yerga yozing
pass

# %% [markdown]
# ---
# ## Vazifa 9. Tana massasi indeksi (BMI)
#
# Vazn (kg) va bo'y (m) ni so'rang. BMI ni hisoblang va toifani chiqaring.
#
# **Formula:** BMI = vazn / bo'y²
#
# | BMI | Toifa |
# |---|---|
# | < 18.5 | Past vazn |
# | 18.5–24.9 | Me'yor |
# | 25–29.9 | Ortiqcha vazn |
# | ≥ 30 | Semizlik |

# %%
# Kodingizni shu yerga yozing
pass

# %% [markdown]
# ---
# ## Vazifa 10. Vaqt konvertori
#
# Sekundlar sonini so'rang. Vaqtni `SS:DD:SS` formatida chiqaring.
#
# **Maslahat:** `//` (butun bo'lish) va `%` (qoldiq) operatorlaridan foydalaning.
#
# **Misol:** 3725 sekund → `01:02:05`

# %%
# Kodingizni shu yerga yozing
pass
