# %% [markdown]
# # Введение в Python — Урок 1
# ## Практические задания
#
# **Темы:** `print`, переменные, типы данных, `input`, f-строки, операции, условия `if / elif / else`
#
# Задания выполняются последовательно. Замените `pass` на ваш код и запустите ячейку (Shift + Enter).

# %% [markdown]
# ---
# ## Задание 1. Карточка знакомства
#
# Запросить у пользователя имя, фамилию и город. Вывести оформленную карточку через f-строки.
#
# **Пример вывода:**
# ```
# Имя:     Миркомиль
# Фамилия: Каримов
# Город:   Ташкент
# ```

# %%
# Ваш код здесь
pass

# %% [markdown]
# ---
# ## Задание 2. Площадь и периметр прямоугольника
#
# Запросить длину и ширину прямоугольника. Вывести площадь и периметр.
#
# **Подсказка:** для дробных чисел используйте `float()`.
#
# **Пример вывода:**
# ```
# Площадь:  15.0
# Периметр: 16.0
# ```

# %%
# Ваш код здесь
pass

# %% [markdown]
# ---
# ## Задание 3. Конвертер температуры
#
# Запросить температуру в градусах Цельсия. Вывести значение в градусах Фаренгейта.
#
# **Формула:** F = C × 9/5 + 32
#
# **Пример вывода:**
# ```
# 0°C = 32.0°F
# ```

# %%
# Ваш код здесь
pass

# %% [markdown]
# ---
# ## Задание 4. Калькулятор чаевых
#
# Запросить сумму счёта и процент чаевых. Вывести сумму чаевых и итог.
#
# **Пример вывода:**
# ```
# Сумма счёта:  1000
# Чаевые (10%): 100.0
# Итого:        1100.0
# ```

# %%
# Ваш код здесь
pass

# %% [markdown]
# ---
# ## Задание 5. Чётность числа
#
# Запросить целое число. Вывести:
# - «Ноль» если число равно нулю
# - «Чётное» если делится на 2 без остатка
# - «Нечётное» в остальных случаях
#
# **Подсказка:** оператор `%` возвращает остаток от деления.

# %%
# Ваш код здесь
pass

# %% [markdown]
# ---
# ## Задание 6. Калькулятор оценок
#
# Запросить балл от 0 до 100. Вывести буквенную оценку.
#
# | Балл | Оценка |
# |---|---|
# | ≥ 90 | A |
# | ≥ 80 | B |
# | ≥ 70 | C |
# | ≥ 60 | D |
# | < 60 | F |

# %%
# Ваш код здесь
pass

# %% [markdown]
# ---
# ## Задание 7. Категория возраста
#
# Запросить возраст. Вывести категорию.
#
# | Возраст | Категория |
# |---|---|
# | 0–12 | Ребёнок |
# | 13–17 | Подросток |
# | 18–64 | Взрослый |
# | 65+ | Пенсионер |

# %%
# Ваш код здесь
pass

# %% [markdown]
# ---
# ## Задание 8. Високосный год
#
# Запросить год. Определить, является ли он високосным.
#
# **Правило:** год является високосным, если он делится на 4, кроме случаев, когда он делится на 100, но не на 400.
#
# **Примеры:**
# - 2024 → високосный (делится на 4, не на 100)
# - 2000 → високосный (делится на 400)
# - 1900 → не високосный (делится на 100, но не на 400)
# - 2023 → не високосный (не делится на 4)

# %%
# Ваш код здесь
pass

# %% [markdown]
# ---
# ## Задание 9. Индекс массы тела (BMI)
#
# Запросить вес (кг) и рост (м). Рассчитать BMI и вывести категорию.
#
# **Формула:** BMI = вес / рост²
#
# | BMI | Категория |
# |---|---|
# | < 18.5 | Недостаточный вес |
# | 18.5–24.9 | Норма |
# | 25–29.9 | Избыточный вес |
# | ≥ 30 | Ожирение |

# %%
# Ваш код здесь
pass

# %% [markdown]
# ---
# ## Задание 10. Конвертер времени
#
# Запросить количество секунд. Вывести время в формате `ЧЧ:ММ:СС`.
#
# **Подсказка:** используйте `//` (целочисленное деление) и `%` (остаток).
#
# **Пример:** 3725 секунд → `01:02:05`

# %%
# Ваш код здесь
pass
